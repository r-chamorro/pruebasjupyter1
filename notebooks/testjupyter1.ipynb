# %%
import  sys
sys.path.append("../src")
from data_loader import load_csv

df = load_csv("../data/videogamesplaydata.csv")
df.head()
# Out:
#     Game Name                   Genre        Platform  Release Year  \
# 0  Valorant 1                    MOBA  Multi-platform          2018
# 1      PUBG 2  Party/Social Deduction         Console          2016
# 2    Dota 2 3                  Sports          Mobile          2014
# 3  Valorant 4  Party/Social Deduction              PC          2008
# 4     CS:GO 5                  Sports          Mobile          2017
#
#    Total Players (Millions)  Total Installs (Millions)      Developer  \
# 0                       583                        628          Valve
# 1                       322                        335  Infinity Ward
# 2                       437                        618          Valve
# 3                       223                        377         Mojang
# 4                       496                        655  Infinity Ward
#
#    Avg Playtime (hrs/week) Online Multiplayer
# 0                      6.3                 No
# ...

# %%
print("Hola Mundo")
# Out:
# Hola Mundo

# %%
print("Adiós Mundo")
# Out:
# Adiós Mundo
